# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('../../data/funda_train.csv')

dataset['year_month'] = dataset['transacted_date'].str[0:7]

# %%
subset = dataset[['store_id','amount','year_month','card_id']]
subset
# Out:
#          store_id       amount year_month  card_id
# 0               0  1857.142857    2016-06        0
# 1               0   857.142857    2016-06        1
# 2               0  2000.000000    2016-06        2
# 3               0  7857.142857    2016-06        3
# 4               0  2000.000000    2016-06        4
# ...           ...          ...        ...      ...
# 6556608      2136 -4500.000000    2019-02  4663855
# 6556609      2136  4142.857143    2019-02  4663855
# 6556610      2136  4500.000000    2019-02  4663489
# 6556611      2136   571.428571    2019-02  4663856
# 6556612      2136  5857.142857    2019-02  4658616
#
# [6556613 rows x 4 columns]

# %%
dataset # store_id 를 기준으로 내림차순
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               0        4            c      2016-06-02           11:06
# ...           ...      ...          ...             ...             ...
# 6556608      2136  4663855            d      2019-02-28           23:20
# 6556609      2136  4663855            d      2019-02-28           23:24
# 6556610      2136  4663489            a      2019-02-28           23:24
# 6556611      2136  4663856            d      2019-02-28           23:27
# 6556612      2136  4658616            c      2019-02-28           23:54
#
#          installment_term  region type_of_business       amount year_month
# ...

# %%
dataset.iloc[40:42]
# Out:
#     store_id  card_id card_company transacted_date transacted_time  \
# 40         0       40            a      2016-06-10           17:25
# 41         0       40            a      2016-06-10           17:26
#
#     installment_term region type_of_business       amount year_month
# 40                 2    NaN           기타 미용업  8571.428571    2016-06
# 41                 2    NaN           기타 미용업 -8571.428571    2016-06

# %%
dataset.iloc[7388:7399]
# Out:
#       store_id  card_id card_company transacted_date transacted_time  \
# 7388         1     3009            b      2018-06-14           14:32
# 7389         1     2922            f      2018-06-14           15:41
# 7390         1     2922            f      2018-06-14           15:42
# 7391         1     2922            f      2018-06-14           15:43
# 7392         1     2922            f      2018-06-14           15:43
# 7393         1     2922            f      2018-06-14           15:43
# 7394         1     3090            g      2018-06-14           16:34
# 7395         1     2941            c      2018-06-14           16:42
# 7396         1     2417            a      2018-06-15           11:53
# 7397         1     2275            a      2018-06-15           12:53
# 7398         1     3090            g      2018-06-15           15:54
#
#       installment_term region type_of_business       amount year_month
# ...

# %%
refund = subset[subset['amount'] < 0]
refund
# Out:
#          store_id        amount year_month  card_id
# 41              0  -8571.428571    2016-06       40
# 347             0  -1857.142857    2016-08      285
# 731             0  -2000.000000    2016-10      473
# 831             0    -85.714286    2016-11      230
# 944             0    -57.142857    2016-11      138
# ...           ...           ...        ...      ...
# 6556242      2136 -13428.571429    2019-02  4663626
# 6556448      2136  -6928.571429    2019-02  4663760
# 6556485      2136  -5571.428571    2019-02  4663779
# 6556489      2136  -8571.428571    2019-02  4663780
# 6556608      2136  -4500.000000    2019-02  4663855
#
# [73100 rows x 4 columns]

# %%
refund
# Out:
#          store_id        amount year_month  card_id
# 41              0  -8571.428571    2016-06       40
# 347             0  -1857.142857    2016-08      285
# 731             0  -2000.000000    2016-10      473
# 831             0    -85.714286    2016-11      230
# 944             0    -57.142857    2016-11      138
# ...           ...           ...        ...      ...
# 6556242      2136 -13428.571429    2019-02  4663626
# 6556448      2136  -6928.571429    2019-02  4663760
# 6556485      2136  -5571.428571    2019-02  4663779
# 6556489      2136  -8571.428571    2019-02  4663780
# 6556608      2136  -4500.000000    2019-02  4663855
#
# [73100 rows x 4 columns]

# %%
dataset
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               0        4            c      2016-06-02           11:06
# ...           ...      ...          ...             ...             ...
# 6556608      2136  4663855            d      2019-02-28           23:20
# 6556609      2136  4663855            d      2019-02-28           23:24
# 6556610      2136  4663489            a      2019-02-28           23:24
# 6556611      2136  4663856            d      2019-02-28           23:27
# 6556612      2136  4658616            c      2019-02-28           23:54
#
#          installment_term  region type_of_business       amount year_month
# ...

# %%
refund.iloc[0]
# Out:
# store_id                0
# amount       -8571.428571
# year_month        2016-06
# card_id                40
# Name: 41, dtype: object

# %%
dataset.loc[(dataset['amount'] == abs(refund.iloc[0].amount))]
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 35              0       35            g      2016-06-09           21:38
# 36              0       36            g      2016-06-09           21:38
# 40              0       40            a      2016-06-10           17:25
# 42              0       40            a      2016-06-10           17:26
# 53              0       51            g      2016-06-11           21:24
# ...           ...      ...          ...             ...             ...
# 6555672      2136  4663283            g      2018-12-13           02:04
# 6555806      2136  4663339            a      2018-12-23           02:20
# 6555943      2136  4663453            d      2019-01-01           01:03
# 6556488      2136  4663780            d      2019-02-18           21:43
# 6556598      2136  4661654            a      2019-02-28           01:04
#
#          installment_term  region type_of_business       amount year_month
# ...

# %%
refund
# Out:
#          store_id        amount year_month  card_id
# 41              0  -8571.428571    2016-06       40
# 347             0  -1857.142857    2016-08      285
# 731             0  -2000.000000    2016-10      473
# 831             0    -85.714286    2016-11      230
# 944             0    -57.142857    2016-11      138
# ...           ...           ...        ...      ...
# 6556242      2136 -13428.571429    2019-02  4663626
# 6556448      2136  -6928.571429    2019-02  4663760
# 6556485      2136  -5571.428571    2019-02  4663779
# 6556489      2136  -8571.428571    2019-02  4663780
# 6556608      2136  -4500.000000    2019-02  4663855
#
# [73100 rows x 4 columns]

# %%
dataset.loc[(dataset['amount'] == abs(refund.iloc[0].amount)) & (dataset['card_id'] == (refund.iloc[0].card_id))]
# Out:
#     store_id  card_id card_company transacted_date transacted_time  \
# 40         0       40            a      2016-06-10           17:25
# 42         0       40            a      2016-06-10           17:26
#
#     installment_term region type_of_business       amount year_month
# 40                 2    NaN           기타 미용업  8571.428571    2016-06
# 42                 2    NaN           기타 미용업  8571.428571    2016-06

# %%
dataset[refund['amount']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15068/3981266973.py in <module>
# ----> 1 dataset[refund['amount']]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
# ...

# %%
subset = dataset.iloc[refund.index[0]-1 : refund.index[0] + 1]
subset['amount'].sum()
# Out:
# 0.0

# %%
subs = dataset.iloc[refund.index[0]-1 : refund.index[0] + 1]

# %%
subs['amount'].sum()
# Out:
# 0.0

# %%
subs['amount'].sum()
# Out:
# 0.0

# %%
refund_case = []
for i in range(len(refund.index)):
    subset = dataset.iloc[refund.index[i]-1 : refund.index[i] + 1]
    if subset['amount'].sum() == 0:
        refund_case.append(1)
    else:
        refund_case.append(0)

# %%
refund.head(10)
# Out:
#       store_id        amount year_month  card_id
# 41           0  -8571.428571    2016-06       40
# 347          0  -1857.142857    2016-08      285
# 731          0  -2000.000000    2016-10      473
# 831          0    -85.714286    2016-11      230
# 944          0    -57.142857    2016-11      138
# 1953         0 -18285.714286    2017-07      829
# 2659         0  -7142.857143    2017-12     1182
# 2734         0    -18.571429    2018-01     1080
# 3256         0  -2000.000000    2018-05      626
# 3544         0  -5000.000000    2018-07     1401

# %%
npcase = np.array(refund_case)
print(npcase.sum()/len(npcase)*100,"%")
# Out:
# 75.7140902872777 %
